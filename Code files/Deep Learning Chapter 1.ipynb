# %% [markdown]
# # What is Deep Learning ?
# **Deep learning is a subset of machine learning, which is a field dedicated to the study and
# development of machines that can learn (sometimes with the goal of eventually attaining
# general artificial intelligence).**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Now What is machine learning?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# In short a computer code observes the pattern and try to apply it on unseen examples.
#
# ![image-2.png](attachment:image-2.png)
#
# Like baby monkeys learn from the big monkeys and apply same thing to anpther people to get food or to scare them

# %% [markdown]
# # Are there any types of machine learning, if yes please tell in short ?
# In general, there are two types of machine learning:
# - Supervised ML:
#
# Supervised learning is a method for transforming one dataset into another.
#
# or
#
# When we have to predict values based on given data set
#
# or
#
# when the outcome is given in training dataset
#
# ![image-2.png](attachment:image-2.png)
#
# for example:
#
# ![image.png](attachment:image.png)
#
#
# - Unsupervised ML:
#
# it transforms one dataset into another. But the dataset that it transforms into is not previously known or understood.
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # How does that code works?
# ## it works in three steps:
#
# ## 1. Predict anything: Few may be worng or few may be right
# ## 2. Compare prediction to the truth pattern
# ## 3. Improve: Done :)

# %% [markdown]
# <a href="Deep Learning Chapter 2.ipynb"><h2 align=right>Next &raquo;</h2></a>
